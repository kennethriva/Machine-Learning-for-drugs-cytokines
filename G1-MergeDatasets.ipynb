# %% [markdown]
# ## G1 merge datasets
#
# Simulate the Chembl drug information from the initial Chembl dataset:
# - create all the experimental conditions

# %%
import pandas as pd
import os
import ds_utils

# %%
WorkingFolder = './datasets/'
ExperimCondList = ['STANDARD_TYPE_UNITSj','ASSAY_CHEMBLID','ASSAY_TYPE','ASSAY_ORGANISM',
                   'ORGANISM','TARGET_CHEMBLID']

# %%
# details with MAs (ds_G1_raw0.csv was created manually)
df_det = pd.read_csv(os.path.join(WorkingFolder, 'ds_details.csv'))
df_new = pd.read_csv(os.path.join(WorkingFolder, 'ds_G1_raw0.csv'))

# %% [markdown]
# Get PROTEIN_ACCESSION from details file:

# %%
df_pa =df_det[['PROTEIN_ACCESSION','TARGET_CHEMBLID']].drop_duplicates()
df_pa
# Out:
#       PROTEIN_ACCESSION TARGET_CHEMBLID
# 0                O15264   CHEMBL2094115
# 842              Q16539       CHEMBL260
# 7893             P36888      CHEMBL1974
# 12513            Q96BR1      CHEMBL6186
# 13640            Q9H4B4      CHEMBL4897
# 14359            P13500   CHEMBL1649052
# 14424            P17181      CHEMBL1887
# 14425            Q99988   CHEMBL3120039
# 14432            P13501   CHEMBL1275217
# 14461            O35235   CHEMBL3596084
# 14483            Q00342   CHEMBL2034796
# 14490            Q9QZM3   CHEMBL2176788

# %% [markdown]
# Merge PROTEIN_ACCESSION to G1:

# %%
df_last = pd.merge(df_new, df_pa, on=['TARGET_CHEMBLID'])
df_last.head()
# Out:
#   CMPD_CHEMBLID                  CANONICAL_SMILES  PROTEIN_ACCESSION_x  \
# 0            G1  Br\C(=C\c1oc(Br)cc1)[N+]([O-])=O                  NaN
# 1            G1  Br\C(=C\c1oc(Br)cc1)[N+]([O-])=O                  NaN
# 2            G1  Br\C(=C\c1oc(Br)cc1)[N+]([O-])=O                  NaN
# 3            G1  Br\C(=C\c1oc(Br)cc1)[N+]([O-])=O                  NaN
# 4            G1  Br\C(=C\c1oc(Br)cc1)[N+]([O-])=O                  NaN
#
#    ACTIVITY_ID STANDARD_TYPE_UNITSj  STANDARD_VALUE ASSAY_CHEMBLID ASSAY_TYPE  \
# 0          NaN       Inhibition (%)             NaN   CHEMBL819807          F
# 1          NaN       Inhibition (%)             NaN   CHEMBL819808          F
# 2          NaN       Inhibition (%)             NaN   CHEMBL818993          F
# 3          NaN            IC50 (nM)             NaN   CHEMBL818992          F
# 4          NaN            IC50 (nM)             NaN   CHEMBL769660          F
#
#   ASSAY_ORGANISM  CURATED_BY         ...          nRotB  LipinskiFailures  \
# 0   Homo sapiens         NaN         ...              2                 0
# 1   Homo sapiens         NaN         ...              2                 0
# 2   Homo sapiens         NaN         ...              2                 0
# 3   Homo sapiens         NaN         ...              2                 0
# 4   Homo sapiens         NaN         ...              2                 0
#
#   TopoPSA   VAdjMat          MW  WPATH  WPOL  XLogP  Zagreb  \
# 0   56.28  4.584963  294.847967    211    12  2.817      56
# 1   56.28  4.584963  294.847967    211    12  2.817      56
# 2   56.28  4.584963  294.847967    211    12  2.817      56
# 3   56.28  4.584963  294.847967    211    12  2.817      56
# 4   56.28  4.584963  294.847967    211    12  2.817      56
#
#    PROTEIN_ACCESSION_y
# 0               O15264
# 1               O15264
# 2               O15264
# 3               O15264
# 4               O15264
#
# [5 rows x 162 columns]

# %%
# change name
df_last.rename(columns={'PROTEIN_ACCESSION_x': 'PROTEIN_ACCESSION'}, inplace=True)
df_last.columns
# Out:
# Index(['CMPD_CHEMBLID', 'CANONICAL_SMILES', 'PROTEIN_ACCESSION', 'ACTIVITY_ID',
#        'STANDARD_TYPE_UNITSj', 'STANDARD_VALUE', 'ASSAY_CHEMBLID',
#        'ASSAY_TYPE', 'ASSAY_ORGANISM', 'CURATED_BY',
#        ...
#        'nRotB', 'LipinskiFailures', 'TopoPSA', 'VAdjMat', 'MW', 'WPATH',
#        'WPOL', 'XLogP', 'Zagreb', 'PROTEIN_ACCESSION_y'],
#       dtype='object', length=162)

# %%
# place the real values
df_last['PROTEIN_ACCESSION']=df_last['PROTEIN_ACCESSION_y']
df_last.drop('PROTEIN_ACCESSION_y', axis = 1, inplace=True)
df_last.head()
# Out:
#   CMPD_CHEMBLID                  CANONICAL_SMILES PROTEIN_ACCESSION  \
# 0            G1  Br\C(=C\c1oc(Br)cc1)[N+]([O-])=O            O15264
# 1            G1  Br\C(=C\c1oc(Br)cc1)[N+]([O-])=O            O15264
# 2            G1  Br\C(=C\c1oc(Br)cc1)[N+]([O-])=O            O15264
# 3            G1  Br\C(=C\c1oc(Br)cc1)[N+]([O-])=O            O15264
# 4            G1  Br\C(=C\c1oc(Br)cc1)[N+]([O-])=O            O15264
#
#    ACTIVITY_ID STANDARD_TYPE_UNITSj  STANDARD_VALUE ASSAY_CHEMBLID ASSAY_TYPE  \
# 0          NaN       Inhibition (%)             NaN   CHEMBL819807          F
# 1          NaN       Inhibition (%)             NaN   CHEMBL819808          F
# 2          NaN       Inhibition (%)             NaN   CHEMBL818993          F
# 3          NaN            IC50 (nM)             NaN   CHEMBL818992          F
# 4          NaN            IC50 (nM)             NaN   CHEMBL769660          F
#
#   ASSAY_ORGANISM  CURATED_BY   ...   topoShape  nRotB LipinskiFailures  \
# 0   Homo sapiens         NaN   ...        0.75      2                0
# 1   Homo sapiens         NaN   ...        0.75      2                0
# 2   Homo sapiens         NaN   ...        0.75      2                0
# 3   Homo sapiens         NaN   ...        0.75      2                0
# 4   Homo sapiens         NaN   ...        0.75      2                0
#
#    TopoPSA   VAdjMat          MW  WPATH  WPOL  XLogP  Zagreb
# 0    56.28  4.584963  294.847967    211    12  2.817      56
# 1    56.28  4.584963  294.847967    211    12  2.817      56
# 2    56.28  4.584963  294.847967    211    12  2.817      56
# 3    56.28  4.584963  294.847967    211    12  2.817      56
# 4    56.28  4.584963  294.847967    211    12  2.817      56
#
# [5 rows x 161 columns]

# %% [markdown]
# Save the final G1 file to be used to add descriptors, MA, and predictions with the best model:

# %%
# merge first protein descriptor file
df_prot1 = pd.read_csv(os.path.join(WorkingFolder, 'Protein_descriptors.csv'))
df_last2 = pd.merge(df_last, df_prot1, on='PROTEIN_ACCESSION')
df_last2.head()
# Out:
#   CMPD_CHEMBLID                  CANONICAL_SMILES PROTEIN_ACCESSION  \
# 0            G1  Br\C(=C\c1oc(Br)cc1)[N+]([O-])=O            O15264
# 1            G1  Br\C(=C\c1oc(Br)cc1)[N+]([O-])=O            O15264
# 2            G1  Br\C(=C\c1oc(Br)cc1)[N+]([O-])=O            O15264
# 3            G1  Br\C(=C\c1oc(Br)cc1)[N+]([O-])=O            O15264
# 4            G1  Br\C(=C\c1oc(Br)cc1)[N+]([O-])=O            O15264
#
#    ACTIVITY_ID STANDARD_TYPE_UNITSj  STANDARD_VALUE ASSAY_CHEMBLID ASSAY_TYPE  \
# 0          NaN       Inhibition (%)             NaN   CHEMBL819807          F
# 1          NaN       Inhibition (%)             NaN   CHEMBL819808          F
# 2          NaN       Inhibition (%)             NaN   CHEMBL818993          F
# 3          NaN            IC50 (nM)             NaN   CHEMBL818992          F
# 4          NaN            IC50 (nM)             NaN   CHEMBL769660          F
#
#   ASSAY_ORGANISM  CURATED_BY        ...        CHAM810101.lag21  \
# 0   Homo sapiens         NaN        ...                0.986033
# 1   Homo sapiens         NaN        ...                0.986033
# 2   Homo sapiens         NaN        ...                0.986033
# 3   Homo sapiens         NaN        ...                0.986033
# 4   Homo sapiens         NaN        ...                0.986033
#
#    CHAM810101.lag22 CHAM810101.lag23  CHAM810101.lag24  CHAM810101.lag25  \
# 0          1.072765         0.962658          0.952297          1.022723
# 1          1.072765         0.962658          0.952297          1.022723
# 2          1.072765         0.962658          0.952297          1.022723
# 3          1.072765         0.962658          0.952297          1.022723
# 4          1.072765         0.962658          0.952297          1.022723
#
#    CHAM810101.lag26  CHAM810101.lag27  CHAM810101.lag28  CHAM810101.lag29  \
# 0          1.014284          1.027107          1.045441          0.967998
# 1          1.014284          1.027107          1.045441          0.967998
# 2          1.014284          1.027107          1.045441          0.967998
# 3          1.014284          1.027107          1.045441          0.967998
# 4          1.014284          1.027107          1.045441          0.967998
#
#    CHAM810101.lag30
# 0          0.987162
# 1          0.987162
# 2          0.987162
# 3          0.987162
# 4          0.987162
#
# [5 rows x 251 columns]

# %%
# merge 2nd protein descriptor file
df_prot2 = pd.read_csv(os.path.join(WorkingFolder, 'Protein_descriptors2.csv'))
df_last3 = pd.merge(df_last2, df_prot2, on='PROTEIN_ACCESSION')
df_last3.head()
# Out:
#   CMPD_CHEMBLID                  CANONICAL_SMILES PROTEIN_ACCESSION  \
# 0            G1  Br\C(=C\c1oc(Br)cc1)[N+]([O-])=O            O15264
# 1            G1  Br\C(=C\c1oc(Br)cc1)[N+]([O-])=O            O15264
# 2            G1  Br\C(=C\c1oc(Br)cc1)[N+]([O-])=O            O15264
# 3            G1  Br\C(=C\c1oc(Br)cc1)[N+]([O-])=O            O15264
# 4            G1  Br\C(=C\c1oc(Br)cc1)[N+]([O-])=O            O15264
#
#    ACTIVITY_ID STANDARD_TYPE_UNITSj  STANDARD_VALUE ASSAY_CHEMBLID ASSAY_TYPE  \
# 0          NaN       Inhibition (%)             NaN   CHEMBL819807          F
# 1          NaN       Inhibition (%)             NaN   CHEMBL819808          F
# 2          NaN       Inhibition (%)             NaN   CHEMBL818993          F
# 3          NaN            IC50 (nM)             NaN   CHEMBL818992          F
# 4          NaN            IC50 (nM)             NaN   CHEMBL769660          F
#
#   ASSAY_ORGANISM  CURATED_BY    ...      comp_L    comp_K    comp_M    comp_F  \
# 0   Homo sapiens         NaN    ...     0.10411  0.087671  0.035616  0.049315
# 1   Homo sapiens         NaN    ...     0.10411  0.087671  0.035616  0.049315
# 2   Homo sapiens         NaN    ...     0.10411  0.087671  0.035616  0.049315
# 3   Homo sapiens         NaN    ...     0.10411  0.087671  0.035616  0.049315
# 4   Homo sapiens         NaN    ...     0.10411  0.087671  0.035616  0.049315
#
#      comp_P    comp_S    comp_T    comp_W    comp_Y    comp_V
# 0  0.046575  0.057534  0.052055  0.013699  0.041096  0.063014
# 1  0.046575  0.057534  0.052055  0.013699  0.041096  0.063014
# 2  0.046575  0.057534  0.052055  0.013699  0.041096  0.063014
# 3  0.046575  0.057534  0.052055  0.013699  0.041096  0.063014
# 4  0.046575  0.057534  0.052055  0.013699  0.041096  0.063014
#
# [5 rows x 271 columns]

# %%
print('-> Saving the final G1 file ...')
df_last3.to_csv(os.path.join(WorkingFolder, 'ds.G1_raw.csv'), index=False)
print('Done!')
# Out:
# -> Saving the final G1 file ...
# Done!
