# %% [markdown]
# # Plots

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt

WorkingFolder     = './'

# %% [markdown]
# ### Baseline plot
#
# Read baseline results, order by MLA Name in the script, unify data and plot for FS and PCA dataset.

# %%
# read the CSV file as dataframe
df = pd.read_csv(os.path.join(WorkingFolder, "ML_baseline_generator.csv"))

# %% [markdown]
# Create a new dataframe with the classifiers in the script order:

# %%
classifiers =['KNeighborsClassifier','GaussianNB',
              'LinearSVC', 'LogisticRegression','LinearDiscriminantAnalysis','SVC(linear)',
              'SVC(rbf)',
              'AdaBoostClassifier', 'MLPClassifier', 
              'DecisionTreeClassifier', 'RandomForestClassifier',
              'GradientBoostingClassifier', 'BaggingClassifier','XGBClassifier']

# %%
dfc = pd.DataFrame(columns=['MLA Name'])

# %%
dfc['MLA Name'] = classifiers
dfc
# Out:
#                       MLA Name
# 0         KNeighborsClassifier
# 1                   GaussianNB
# 2                    LinearSVC
# 3           LogisticRegression
# 4   LinearDiscriminantAnalysis
# 5                  SVC(linear)
# 6                     SVC(rbf)
# 7           AdaBoostClassifier
# 8                MLPClassifier
# 9       DecisionTreeClassifier
# 10      RandomForestClassifier
# 11  GradientBoostingClassifier
# 12           BaggingClassifier
# 13               XGBClassifier

# %%
dfx = pd.merge(dfc, df, on=['MLA Name'])
dfx
# Out:
#                       MLA Name             MLA_dataset  MLA Train Accuracy  \
# 0         KNeighborsClassifier    fs-rf.s.ds_MA_tr.csv              0.8540
# 1         KNeighborsClassifier  pca0.99.s.ds_MA_tr.csv              0.8562
# 2         KNeighborsClassifier          s.ds_MA_tr.csv              0.8571
# 3                   GaussianNB    fs-rf.s.ds_MA_tr.csv              0.7032
# 4                   GaussianNB  pca0.99.s.ds_MA_tr.csv              0.7197
# 5                   GaussianNB          s.ds_MA_tr.csv              0.6365
# 6                    LinearSVC    fs-rf.s.ds_MA_tr.csv              0.8181
# 7                    LinearSVC  pca0.99.s.ds_MA_tr.csv              0.8148
# 8                    LinearSVC          s.ds_MA_tr.csv              0.8348
# 9           LogisticRegression    fs-rf.s.ds_MA_tr.csv              0.8215
# 10          LogisticRegression  pca0.99.s.ds_MA_tr.csv              0.8126
# 11          LogisticRegression          s.ds_MA_tr.csv              0.8356
# 12  LinearDiscriminantAnalysis    fs-rf.s.ds_MA_tr.csv              0.8316
# 13  LinearDiscriminantAnalysis  pca0.99.s.ds_MA_tr.csv              0.8285
# 14  LinearDiscriminantAnalysis          s.ds_MA_tr.csv              0.8523
# 15                 SVC(linear)    fs-rf.s.ds_MA_tr.csv              0.8214
# 16                 SVC(linear)  pca0.99.s.ds_MA_tr.csv              0.8159
# 17                 SVC(linear)          s.ds_MA_tr.csv              0.8317
# 18                    SVC(rbf)    fs-rf.s.ds_MA_tr.csv              0.8249
# 19                    SVC(rbf)  pca0.99.s.ds_MA_tr.csv              0.8681
# 20                    SVC(rbf)          s.ds_MA_tr.csv              0.8394
# 21          AdaBoostClassifier    fs-rf.s.ds_MA_tr.csv              0.8373
# 22          AdaBoostClassifier  pca0.99.s.ds_MA_tr.csv              0.8150
# 23          AdaBoostClassifier          s.ds_MA_tr.csv              0.8429
# 24               MLPClassifier    fs-rf.s.ds_MA_tr.csv              0.8629
# 25               MLPClassifier  pca0.99.s.ds_MA_tr.csv              0.9098
# 26               MLPClassifier          s.ds_MA_tr.csv              0.9067
# 27      DecisionTreeClassifier    fs-rf.s.ds_MA_tr.csv              0.9664
# 28      DecisionTreeClassifier  pca0.99.s.ds_MA_tr.csv              0.9664
# 29      DecisionTreeClassifier          s.ds_MA_tr.csv              0.9664
# 30      RandomForestClassifier    fs-rf.s.ds_MA_tr.csv              0.9664
# 31      RandomForestClassifier  pca0.99.s.ds_MA_tr.csv              0.9663
# 32      RandomForestClassifier          s.ds_MA_tr.csv              0.9664
# 33  GradientBoostingClassifier    fs-rf.s.ds_MA_tr.csv              0.8599
# 34  GradientBoostingClassifier  pca0.99.s.ds_MA_tr.csv              0.8541
# 35  GradientBoostingClassifier          s.ds_MA_tr.csv              0.8721
# 36           BaggingClassifier    fs-rf.s.ds_MA_tr.csv              0.9591
# 37           BaggingClassifier  pca0.99.s.ds_MA_tr.csv              0.9545
# 38           BaggingClassifier          s.ds_MA_tr.csv              0.9590
# 39               XGBClassifier    fs-rf.s.ds_MA_tr.csv              0.9617
# 40               XGBClassifier  pca0.99.s.ds_MA_tr.csv              0.9664
# 41               XGBClassifier          s.ds_MA_tr.csv              0.9663
#
#     MLA Test Accuracy      MLA Test Precission          MLA Test Recall  \
# 0              0.7930  [0.84640259 0.61752988]  [0.8790932  0.55029586]
# 1              0.7945  [0.84643289 0.62198391]  [0.88161209 0.54911243]
# 2              0.7973  [0.84754626 0.62887989]  [0.8845508  0.55147929]
# 3              0.7075  [0.84902913 0.45758355]  [0.73425693 0.63195266]
# 4              0.7208  [0.80113867 0.46354167]  [0.8270361  0.42130178]
# 5              0.6439  [0.86587537 0.40142672]  [0.6125105  0.73254438]
# 6              0.8234  [0.95345345 0.61187958]  [0.79974811 0.88994083]
# 7              0.8187  [0.93765222 0.61073254]  [0.80814442 0.84852071]
# 8              0.8327  [0.97037794 0.62017336]  [0.79764903 0.93136095]
# 9              0.8240  [0.9420078  0.61787234]  [0.81150294 0.8591716 ]
# 10             0.8147  [0.93897638 0.60334728]  [0.80100756 0.85325444]
# 11             0.8333  [0.9661274  0.62289832]  [0.802267   0.92071006]
# 12             0.8355  [0.92356979 0.65067179]  [0.84718724 0.80236686]
# 13             0.8286  [0.89812799 0.65698925]  [0.86607893 0.72307692]
# 14             0.8413  [0.91890681 0.66733668]  [0.86104114 0.78579882]
# 15             0.8265  [0.96813977 0.61124122]  [0.79093199 0.92662722]
# 16             0.8231  [0.93765104 0.61830743]  [0.81444165 0.84733728]
# 23           0.687117      0.794808                       0.569104
# 24           0.647440      0.761632                       0.521485
# 25           0.630620      0.752664                       0.493400
# 26           0.639582      0.757396                       0.508559
# 27           0.573309      0.710594                       0.424316
# 28           0.527550      0.680000                       0.357844
# 29           0.562760      0.703685                       0.408786
# 30           0.642570      0.760412                       0.510937
# 31           0.537692      0.685775                       0.406356
# 32           0.637850      0.755697                       0.507211
# 33           0.715546      0.816853                       0.607804
# 34           0.635973      0.750673                       0.513946
# 35           0.703456      0.806622                       0.591729
# 36           0.626129      0.745560                       0.496755
# 37           0.573770      0.709197                       0.437346
# 38           0.608643      0.734089                       0.472597
# 39           0.591888      0.720496                       0.462732
# 40           0.555919      0.697113                       0.424076
# 41           0.609337      0.733248                       0.478426

# %%
set(dfx["MLA_dataset"])
# Out:
# {'fs-rf.s.ds_MA_tr.csv', 'pca0.99.s.ds_MA_tr.csv', 's.ds_MA_tr.csv'}

# %% [markdown]
# Replace names of datasets:

# %%
#dfx["MLA_dataset"]= dfx["MLA_dataset"].str.replace("pca0.99.o.ds_MA_NoOutliers_tr.csv",
#                                                   "Raw-PCA.ds", case = False)
dfx["MLA_dataset"]= dfx["MLA_dataset"].str.replace("pca0.99.s.ds_MA_tr.csv",
                                                   "Std-PCA.ds", case = False)
#dfx["MLA_dataset"]= dfx["MLA_dataset"].str.replace("fs-rf.o.ds_MA_NoOutliers_tr.csv",
#                                                   "Raw-FS.ds", case = False)
dfx["MLA_dataset"]= dfx["MLA_dataset"].str.replace("fs-rf.s.ds_MA_tr.csv",
                                                   "Std-FS.ds", case = False)
#dfx["MLA_dataset"]= dfx["MLA_dataset"].str.replace("o.ds_MA_NoOutliers_tr.csv",
#                                                   "Raw.ds", case = False)
dfx["MLA_dataset"]= dfx["MLA_dataset"].str.replace("s.ds_MA_tr.csv",
                                                   "Std.ds", case = False)
dfx
# Out:
#                       MLA Name MLA_dataset  MLA Train Accuracy  \
# 0         KNeighborsClassifier   Std-FS.ds              0.8540
# 1         KNeighborsClassifier  Std-PCA.ds              0.8562
# 2         KNeighborsClassifier      Std.ds              0.8571
# 3                   GaussianNB   Std-FS.ds              0.7032
# 4                   GaussianNB  Std-PCA.ds              0.7197
# 5                   GaussianNB      Std.ds              0.6365
# 6                    LinearSVC   Std-FS.ds              0.8181
# 7                    LinearSVC  Std-PCA.ds              0.8148
# 8                    LinearSVC      Std.ds              0.8348
# 9           LogisticRegression   Std-FS.ds              0.8215
# 10          LogisticRegression  Std-PCA.ds              0.8126
# 11          LogisticRegression      Std.ds              0.8356
# 12  LinearDiscriminantAnalysis   Std-FS.ds              0.8316
# 13  LinearDiscriminantAnalysis  Std-PCA.ds              0.8285
# 14  LinearDiscriminantAnalysis      Std.ds              0.8523
# 15                 SVC(linear)   Std-FS.ds              0.8214
# 16                 SVC(linear)  Std-PCA.ds              0.8159
# 17                 SVC(linear)      Std.ds              0.8317
# 18                    SVC(rbf)   Std-FS.ds              0.8249
# 19                    SVC(rbf)  Std-PCA.ds              0.8681
# 20                    SVC(rbf)      Std.ds              0.8394
# 21          AdaBoostClassifier   Std-FS.ds              0.8373
# 22          AdaBoostClassifier  Std-PCA.ds              0.8150
# 23          AdaBoostClassifier      Std.ds              0.8429
# 24               MLPClassifier   Std-FS.ds              0.8629
# 25               MLPClassifier  Std-PCA.ds              0.9098
# 26               MLPClassifier      Std.ds              0.9067
# 27      DecisionTreeClassifier   Std-FS.ds              0.9664
# 28      DecisionTreeClassifier  Std-PCA.ds              0.9664
# 29      DecisionTreeClassifier      Std.ds              0.9664
# 30      RandomForestClassifier   Std-FS.ds              0.9664
# 31      RandomForestClassifier  Std-PCA.ds              0.9663
# 32      RandomForestClassifier      Std.ds              0.9664
# 33  GradientBoostingClassifier   Std-FS.ds              0.8599
# 34  GradientBoostingClassifier  Std-PCA.ds              0.8541
# 35  GradientBoostingClassifier      Std.ds              0.8721
# 36           BaggingClassifier   Std-FS.ds              0.9591
# 37           BaggingClassifier  Std-PCA.ds              0.9545
# 38           BaggingClassifier      Std.ds              0.9590
# 39               XGBClassifier   Std-FS.ds              0.9617
# 40               XGBClassifier  Std-PCA.ds              0.9664
# 41               XGBClassifier      Std.ds              0.9663
#
#     MLA Test Accuracy      MLA Test Precission          MLA Test Recall  \
# 0              0.7930  [0.84640259 0.61752988]  [0.8790932  0.55029586]
# 1              0.7945  [0.84643289 0.62198391]  [0.88161209 0.54911243]
# 2              0.7973  [0.84754626 0.62887989]  [0.8845508  0.55147929]
# 3              0.7075  [0.84902913 0.45758355]  [0.73425693 0.63195266]
# 4              0.7208  [0.80113867 0.46354167]  [0.8270361  0.42130178]
# 5              0.6439  [0.86587537 0.40142672]  [0.6125105  0.73254438]
# 6              0.8234  [0.95345345 0.61187958]  [0.79974811 0.88994083]
# 7              0.8187  [0.93765222 0.61073254]  [0.80814442 0.84852071]
# 8              0.8327  [0.97037794 0.62017336]  [0.79764903 0.93136095]
# 9              0.8240  [0.9420078  0.61787234]  [0.81150294 0.8591716 ]
# 10             0.8147  [0.93897638 0.60334728]  [0.80100756 0.85325444]
# 11             0.8333  [0.9661274  0.62289832]  [0.802267   0.92071006]
# 12             0.8355  [0.92356979 0.65067179]  [0.84718724 0.80236686]
# 13             0.8286  [0.89812799 0.65698925]  [0.86607893 0.72307692]
# 14             0.8413  [0.91890681 0.66733668]  [0.86104114 0.78579882]
# 15             0.8265  [0.96813977 0.61124122]  [0.79093199 0.92662722]
# 16             0.8231  [0.93765104 0.61830743]  [0.81444165 0.84733728]
# 17             0.8351  [0.96859169 0.62490024]  [0.80268682 0.92662722]
# 18             0.8224  [0.94622595 0.61333333]  [0.80520571 0.87100592]
# 19             0.8125  [0.92860589 0.60398614]  [0.80814442 0.82485207]
# 20             0.8289  [0.95979899 0.61843169]  [0.80184719 0.90532544]
# 21             0.8327  [0.90008688 0.66486486]  [0.86985726 0.72781065]
# 22             0.8063  [0.8501395  0.65320334]  [0.89546599 0.55502959]
# 23             0.8262  [0.89951733 0.64978903]  [0.86062133 0.72899408]
# 36           0.626129      0.745560                       0.496755
# 37           0.573770      0.709197                       0.437346
# 38           0.608643      0.734089                       0.472597
# 39           0.591888      0.720496                       0.462732
# 40           0.555919      0.697113                       0.424076
# 41           0.609337      0.733248                       0.478426

# %% [markdown]
# Replace some column names:

# %%
dfx.rename(columns={'MLA Name':'Classifier',
                    'MLA Test AUC':'Test AUC',
                    'MLA_dataset':'Dataset'}, 
                 inplace=True)
dfx.head()
# Out:
#              Classifier     Dataset  MLA Train Accuracy  MLA Test Accuracy  \
# 0  KNeighborsClassifier   Std-FS.ds              0.8540             0.7930
# 1  KNeighborsClassifier  Std-PCA.ds              0.8562             0.7945
# 2  KNeighborsClassifier      Std.ds              0.8571             0.7973
# 3            GaussianNB   Std-FS.ds              0.7032             0.7075
# 4            GaussianNB  Std-PCA.ds              0.7197             0.7208
#
#        MLA Test Precission          MLA Test Recall  MLA Test F1_score  \
# 0  [0.84640259 0.61752988]  [0.8790932  0.55029586]           0.581977
# 1  [0.84643289 0.62198391]  [0.88161209 0.54911243]           0.583281
# 2  [0.84754626 0.62887989]  [0.8845508  0.55147929]           0.587642
# 3  [0.84902913 0.45758355]  [0.73425693 0.63195266]           0.530815
# 4  [0.80113867 0.46354167]  [0.8270361  0.42130178]           0.441414
#
#    Test AUC  MLA Test Matthews Coefficient
# 0  0.714695                       0.446327
# 1  0.715362                       0.449175
# 2  0.718015                       0.455781
# 3  0.683105                       0.335089
# 4  0.624169                       0.256379

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")

# %%
new = dfx[["Dataset","Classifier","Test AUC"]]
new.head()
# Out:
#       Dataset            Classifier  Test AUC
# 0   Std-FS.ds  KNeighborsClassifier  0.714695
# 1  Std-PCA.ds  KNeighborsClassifier  0.715362
# 2      Std.ds  KNeighborsClassifier  0.718015
# 3   Std-FS.ds            GaussianNB  0.683105
# 4  Std-PCA.ds            GaussianNB  0.624169

# %%
currPallete = sns.color_palette("Paired",12)
sns.palplot(currPallete)

# %%
sns.set_context('poster')

# %%
# 1. Enlarge the plot
plt.figure(figsize=(10,6))
 
sns.swarmplot(x='Test AUC', 
              y='Classifier', 
              data=new, 
              hue='Dataset',
              size=10,
              palette = 'Set1')# 2. Separate points by hue) # 3. Use Pokemon palette
 
# 4. Adjust the y-axis
# plt.ylim(0, 260)
plt.xlim(0.6, 0.9)
 
# 5. Place legend to the right
plt.legend(bbox_to_anchor=(1, 1), loc=2)
plt.grid(True)

# %%
# 1. Enlarge the plot
plt.figure(figsize=(10,6))
 
sns.swarmplot(x='Test AUC', 
              y='Dataset', 
              data=new, 
              hue='Classifier',
              size=10,
              palette = currPallete)# 2. Separate points by hue) # 3. Use Pokemon palette
 
# 4. Adjust the y-axis
# plt.ylim(0, 260)
plt.xlim(0.6, 0.9)
 
# 5. Place legend to the right
plt.legend(bbox_to_anchor=(1, 1), loc=2)
plt.grid(True)
